# %%
import numpy as np
import matplotlib.pyplot as plt
def logspace(start,stop):
    x=[]
    repet=np.log10(stop/start)
    n=repet*10
    for i in range(int(repet)):
        for j in range(1,10):
            x.append(start*j*10**(i))
    x.append(stop)
    return np.array(x)

# %%
'''
f=open("/home/thomas/Documents/0_Stage/My_pimms_prgm/input.txt","w")
f.write("from xmm pn Thin  0.2-2\ninstrument flux ergs 0.2-2 unabsorbed")
Temp=np.linspace(5.6,8.5,int(2.9/0.05))
for T in Temp:
    f.write(f"\nmodel plasma {T} logt 0.8  0\ngo 1000")
f.close()
'''

# %%
f=open("/home/thomas/Documents/0_Stage/My_pimms_prgm/all.txt","r")
liste=f.readlines()
tout=[]
for ligne in liste:
    tout.append([float(x) for x in ligne.split()])
for i in range(len(tout)):
    plt.plot(np.linspace(5.6,8.5,len(tout[i])),tout[i])
plt.yscale('log')
f.close()
